# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Unzip the uploaded file
# !unzip -o '/content/Diamonds Prices2022.csv.zip'
# Out:
# Archive:  /content/Diamonds Prices2022.csv.zip
#   inflating: Diamonds Prices2022.csv

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('/content/Diamonds Prices2022.csv')

print("Dataset loaded successfully. Displaying the first 5 rows:")
display(df.head())

print("\nBasic information about the dataset:")
display(df.info())
# Out:
# Dataset loaded successfully. Displaying the first 5 rows:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
# ...

# %%
# Identify and count missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]

if not missing_values.empty:
    print("Missing values in each column:")
    display(missing_values)
else:
    print("No missing values found in the dataset.")
# Out:
# No missing values found in the dataset.

# %%
# Count initial number of rows
initial_rows = df.shape[0]

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Count rows after removing duplicates
rows_after_duplicates = df.shape[0]

# Report the number of duplicates removed
duplicates_removed = initial_rows - rows_after_duplicates

if duplicates_removed > 0:
    print(f"Successfully removed {duplicates_removed} duplicate rows.")
else:
    print("No duplicate rows found in the dataset.")

print(f"Dataset shape after removing duplicates: {df.shape}")
# Out:
# No duplicate rows found in the dataset.
# Dataset shape after removing duplicates: (53943, 11)

# %%
print("Detecting outliers using the IQR method:")

# Exclude 'Unnamed: 0' as it's typically an index and not a feature for outlier analysis
numerical_cols_for_outliers = [col for col in numerical_cols if col != 'Unnamed: 0']

outlier_summary = {}

for col in numerical_cols_for_outliers:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    if not outliers.empty:
        outlier_summary[col] = {
            'count': len(outliers),
            'percentage': (len(outliers) / len(df)) * 100
        }
    else:
        outlier_summary[col] = {'count': 0, 'percentage': 0.0}

# Display the summary of outliers
if outlier_summary:
    print("\nSummary of Outliers by Column (IQR Method):")
    for col, data in outlier_summary.items():
        print(f"- {col}: {data['count']} outliers ({data['percentage']:.2f}% of total data)")
else:
    print("No numerical columns found or no outliers detected by the IQR method.")
# Out:
# Detecting outliers using the IQR method:
#
# Summary of Outliers by Column (IQR Method):
# - carat: 1889 outliers (3.50% of total data)
# - depth: 2545 outliers (4.72% of total data)
# - table: 605 outliers (1.12% of total data)
# - price: 3540 outliers (6.56% of total data)
# - x: 32 outliers (0.06% of total data)
# - y: 29 outliers (0.05% of total data)
# - z: 49 outliers (0.09% of total data)
